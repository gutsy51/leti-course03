# %%
! pip install ultralytics --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.2/757.2 kB 3.7 MB/s eta 0:00:00

# %%
# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="lp0MTLJfT7JwDGADAZeS")
project = rf.workspace("ilyes-talbi-ptwsp").project("futbol-players")
version = project.version(7)
dataset = version.download("yolov8")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 899.9 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.0 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.18, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to futbol-players-7 in yolov8:: 100%|██████████| 338/338 [00:00<00:00, 5822.50it/s]

# %%
from ultralytics import YOLO

# %%
model=YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 75.2MB/s]

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
model.train(data="/content/yolo_project/datasets/data.yaml", epochs=100, patience=0,
             plots=True, project='/content/yolo_project')
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image

# %%
Image("/content/yolo_project/train/results.png")

# %%
Image("/content/yolo_project/train/F1_curve.png")

# %%
Image("/content/yolo_project/train/PR_curve.png")

# %%
Image("/content/yolo_project/train/P_curve.png")

# %%
Image("/content/yolo_project/train/R_curve.png")

# %%
Image("/content/yolo_project/train/confusion_matrix.png")

# %%
Image("/content/yolo_project/train/val_batch0_labels.jpg")

# %%
Image("/content/yolo_project/train/val_batch0_pred.jpg")

# %%
#Загружаем веса лучшей модели
model.load("/content/yolo_project/train/weights/best.pt");
# Out:
# Transferred 355/355 items from pretrained weights

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/yolo_project/datasets/futbol-players-7/valid/labels.cache... 33 images, 0 backgrounds, 0 corrupt: 100%|██████████| 33/33 [00:00<?, ?it/s]
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:03<00:00,  1.16s/it]
#                    all         33        407      0.912      0.868      0.916      0.575
#                 futbol         33         28      0.869      0.679      0.786      0.364
#                 player         33        359      0.959      0.975       0.99      0.661
#               referree         33         20      0.909       0.95      0.972        0.7
# ...

# %%
source = "https://library.sportingnews.com/2021-08/fifa-18-tackling_1g8n0u9snk1xm1vg6tj3lkwjsl.png"
result=model.predict(source, save=True)
# Out:
# ...
# 100%|██████████| 2.25M/2.25M [00:00<00:00, 37.9MB/s]
# image 1/1 /content/fifa-18-tackling_1g8n0u9snk1xm1vg6tj3lkwjsl.png: 384x640 1 futbol, 20 players, 126.3ms
# Speed: 7.0ms preprocess, 126.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/yolo_project/train3

# %%
Image("/content/yolo_project/train3/fifa-18-tackling_1g8n0u9snk1xm1vg6tj3lkwjsl.png")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
